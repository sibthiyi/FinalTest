# %%
pip install pandas requests
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
#Ambil value key 'data'

import requests

api_url = "https://berita-indo-api-next.vercel.app/api/cnn-news/teknologi"
response = requests.get(api_url)

if response.status_code == 200:
    data = response.json()
    print(data["data"])
    df = pd.DataFrame(data["data"])
else:
    print("Failed to fetch data from the API")
# Out:
# [{'title': 'BAKTI Ungkap 1 Faktor di Luar Kuasa Buat Sebar Internet ke Pelosok', 'link': 'https://www.cnnindonesia.com/teknologi/20231109171655-192-1022137/bakti-ungkap-1-faktor-di-luar-kuasa-buat-sebar-internet-ke-pelosok', 'contentSnippet': 'Badan Aksesibilitas Telekomunikasi dan Informasi (BAKTI) Kominfo menanti pasokan listrik untuk melakukan penyebaran internet di pelosok.', 'isoDate': '2023-11-09T13:14:05.000Z', 'image': {'small': 'https://akcdn.detik.net.id/visual/2023/11/09/dirut-bakti-kominfo-fadhila-matar-3_169.jpeg?w=360&q=90', 'large': 'https://akcdn.detik.net.id/visual/2023/11/09/dirut-bakti-kominfo-fadhila-matar-3_169.jpeg?w=360&q=100'}}, {'title': "Bubble Burst Startup RI Diprediksi Hasilkan 'Blessing in Disguisse'", 'link': 'https://www.cnnindonesia.com/teknologi/20231109165717-206-1022133/bubble-burst-startup-ri-diprediksi-hasilkan-blessing-in-disguisse', 'contentSnippet': 'Fenomena bubble burst sempat dialami banyak startup di Indonesia diramalkan memberi manfaat terselubung. Simak penjelasan CEO BRI Ventures berikut.', 'isoDate': '2023-11-09T12:54:33.000Z', 'image': {'small': 'https://akcdn.detik.net.id/visual/2023/11/09/digital-creative-4_169.jpeg?w=360&q=90', 'large': 'https://akcdn.detik.net.id/visual/2023/11/09/digital-creative-4_169.jpeg?w=360&q=100'}}, {'title': 'Zulhas Akui Tak Anti Asing Buntut Larangan S-Commerce dan Batasi Impor', 'link': 'https://www.cnnindonesia.com/teknologi/20231109183635-206-1022183/zulhas-akui-tak-anti-asing-buntut-larangan-s-commerce-dan-batasi-impor', 'contentSnippet': 'Zulhas\xa0menegaskan pemerintah tidak anti asing ihwal larangan e-commerce menjual berbagai produk impor di bawah Rp1,5 juta dan soal s-commerce.', 'isoDate': '2023-11-09T12:34:39.000Z', 'image': {'small': 'https://akcdn.detik.net.id/visual/2023/11/09/zulkifli-hasan-8_169.jpeg?w=360&q=90', 'large': 'https://akcdn.detik.net.id/visual/2023/11/09/zulkifli-hasan-8_169.jpeg?w=360&q=100'}}, {'title': 'Akademisi Jawab Soal Mimpi Mahasiswa RI Berkarier di Luar Negeri', 'link': 'https://www.cnnindonesia.com/teknologi/20231109184441-199-1022185/akademisi-jawab-soal-mimpi-mahasiswa-ri-berkarier-di-luar-negeri', 'contentSnippet': 'Para dosen dan\xa0praktisi teknologi menjawab soal fenomena kengganan mahasiswa atau peneliti RI pulang dan malah bermimpi berkarier di luar negeri.', 'isoDate': '2023-11-09T12:14:15.000Z', 'image': {'small': 'https://akcdn.detik.net.id/visual/2023/11/09/dialog-panel-shaping-and-revolutionizing-indonesia-creative-industry-1_169.jpeg?w=360&q=90', 'large': 'https://akcdn.detik.net.id/visual/2023/11/09/dialog-panel-shaping-and-revolutionizing-indonesia-creative-industry-1_169.jpeg?w=360&q=100'}}, {'title': 'Grab Akui Pionir Kendaraan Listrik, Pangkas 10 Ribu Ton Emisi', 'link': 'https://www.cnnindonesia.com/teknologi/20231109182516-641-1022175/grab-akui-pionir-kendaraan-listrik-pangkas-10-ribu-ton-emisi', 'contentSnippet': 'Grab Indonesia mengungkap telah memangkas 10 ribu ton emisi karbon dari layanan penyediaan mobil listrik.', 'isoDate': '2023-11-09T11:43:08.000Z', 'image': {'small': 'https://akcdn.detik.net.id/visual/2023/11/09/country-managing-director-grab-indonesia-neneng-goenadi-2_169.jpeg?w=360&q=90', 'large': 'https://akcdn.detik.net.id/visual/2023/11/09/country-managing-director-grab-indonesia-neneng-goenadi-2_169.jpeg?w=360&q=100'}}, {'title': 'Dirut BAKTI Kominfo Cerita Soal Keputusan Bangun Menara BTS 4G', 'link': 'https://www.cnnindonesia.com/teknologi/20231109165129-192-1022120/dirut-bakti-kominfo-cerita-soal-keputusan-bangun-menara-bts-4g', 'contentSnippet': 'Direktur Utama Badan Aksesibilitas Telekomunikasi dan Informasi (BAKTI) Kominfo Fadhilah Mathar menceritakan soal keputusan pemerintah membangun menara BTS 4G', 'isoDate': '2023-11-09T11:21:49.000Z', 'image': {'small': 'https://akcdn.detik.net.id/visual/2023/11/09/dirut-bakti-kominfo-fadhila-matar-1_169.jpeg?w=360&q=90', 'large': 'https://akcdn.detik.net.id/visual/2023/11/09/dirut-bakti-kominfo-fadhila-matar-1_169.jpeg?w=360 ...

# %%
#Transformasi data kolom ‘isoDate’ menjadi tipe data datetime

import pandas as pd

df = pd.DataFrame(news_data)

df['isoDate'] = pd.to_datetime(df['isoDate'])

# %%
df.head
# Out:
# <bound method NDFrame.head of                                                 title  \
# 0   Akademisi Jawab Soal Mimpi Mahasiswa RI Berkar...
# 1   Grab Akui Pionir Kendaraan Listrik, Pangkas 10...
# 2   Dirut BAKTI Kominfo Cerita Soal Keputusan Bang...
# 3   BAKTI Ungkap Angka-angka Menjanjikan Imbas Tra...
# 4         AI Jadi Kurikulum Wajib di Binus University
# ..                                                ...
# 95  Penipuan Mumi 'Putri Duyung' Jepang Terbongkar...
# 96  Microsoft Buka Suara Soal Potensi Kasus Winnie...
# 97  Cara Menggunakan ChatGPT di Laptop dengan Muda...
# 98  Bandung Raya Mulai Musim Hujan, Simak Jadwal L...
# 99  El Nino Masih Cukup Kuat saat Hujan Datang, Pa...
#
#                                                  link  \
# 0   https://www.cnnindonesia.com/teknologi/2023110...
# 1   https://www.cnnindonesia.com/teknologi/2023110...
# 2   https://www.cnnindonesia.com/teknologi/2023110...
# 3   https://www.cnnindonesia.com/teknologi/2023110...
# 4   https://www.cnnindonesia.com/teknologi/2023110...
# ..                                                ...
# 95  https://www.cnnindonesia.com/teknologi/2023110...
# 96  https://www.cnnindonesia.com/teknologi/2023110...
# 97  https://www.cnnindonesia.com/teknologi/2023102...
# 98  https://www.cnnindonesia.com/teknologi/2023110...
# 99  https://www.cnnindonesia.com/teknologi/2023110...
#
#                                        contentSnippet  \
# 0   Para dosen dan praktisi teknologi menjawab soa...
# 1   Grab Indonesia mengungkap telah memangkas 10 r...
# 2   Direktur Utama Badan Aksesibilitas Telekomunik...
# 3   Direktur Utama BAKTI Kominfo Fadhilah Mathar m...
# 4   Rektor Binus University Dr Nelly mengatakan ke...
# ..                                                ...
# 95  Mumi 'putri duyung' Jepang, yang menuai perdeb...
# 96  Microsoft menjawab soal potensi insiden sensor...
# 97  ChatGPT adalah machine learning dengan kecerda...
# 98  BMKG memprakirakan awal musim hujan di wilayah...
# 99  BMKG mengungkap fenomena pengering hujan atau ...
#
#                      isoDate  \
# 0  2023-11-09 12:14:15+00:00
# 1  2023-11-09 11:43:08+00:00
# 2  2023-11-09 11:21:49+00:00
# 3  2023-11-09 11:14:44+00:00
# 4  2023-11-09 10:16:26+00:00
# ..                       ...
# 95 2023-11-02 03:20:09+00:00
# 96 2023-11-02 02:17:04+00:00
# 97 2023-11-02 02:00:43+00:00
# 98 2023-11-02 01:17:02+00:00
# 99 2023-11-02 00:15:41+00:00
#
#                                                 image
# 0   {'small': 'https://akcdn.detik.net.id/visual/2...
# 1   {'small': 'https://akcdn.detik.net.id/visual/2...
# 2   {'small': 'https://akcdn.detik.net.id/visual/2...
# 3   {'small': 'https://akcdn.detik.net.id/visual/2...
# 4   {'small': 'https://akcdn.detik.net.id/visual/2...
# ..                                                ...
# 95  {'small': 'https://akcdn.detik.net.id/visual/2...
# 96  {'small': 'https://akcdn.detik.net.id/visual/2...
# 97  {'small': 'https://akcdn.detik.net.id/visual/2...
# 98  {'small': 'https://akcdn.detik.net.id/visual/2...
# 99  {'small': 'https://akcdn.detik.net.id/visual/2...
#
# [100 rows x 5 columns]>
